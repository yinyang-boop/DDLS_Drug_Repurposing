# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Check GPU availability
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"GPU device: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.8.0+cu126
# CUDA available: True
# CUDA version: 12.6
# GPU device: Tesla T4

# %%
import zipfile
import os

# 1. 设定路径 (请根据您在Drive中的实际位置修改)
DRIVE_PATH = '/content/drive/MyDrive/Colab_Projects' # 假设放在这个文件夹
ZIP_FILE_NAME = 'DDLS_Drug_Repurposing.zip' # 压缩包名字

# 2. 解压文件
zip_path = os.path.join(DRIVE_PATH, ZIP_FILE_NAME)
extract_dir = '/content/DDLS_Drug_Repurposing' # 解压到 Colab 临时环境的这个目录

if not os.path.exists(extract_dir):
    os.makedirs(extract_dir, exist_ok=True)
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)
    print(f"文件已解压到: {extract_dir}")
else:
    print(f"目录 {extract_dir} 已存在，跳过解压。")

# 3. 导航到正确的目录 (如果需要，但加载文件时使用绝对路径更保险)
os.chdir(extract_dir)
print(f"当前工作目录: {os.getcwd()}")
# Out:
# 文件已解压到: /content/DDLS_Drug_Repurposing
# 当前工作目录: /content/DDLS_Drug_Repurposing

# %%
# !pip install torch pandas numpy scikit-learn scipy
# 如果 torch 没有自动安装 GPU 版本，可能需要手动安装，但 Colab GPU 运行时通常自带。
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)

# %%
import os

# 假设外部目录是 /content/DDLS_Drug_Repurposing
OUTER_DIR = '/content/DDLS_Drug_Repurposing'
INNER_DIR_NAME = 'DDLS_Drug_Repurposing' # 内部文件夹的名称

# 拼接出真正的项目根目录
NEW_CWD = os.path.join(OUTER_DIR, INNER_DIR_NAME)

# 切换工作目录
os.chdir(NEW_CWD)
print(f"工作目录已切换到: {os.getcwd()}")
# Out:
# 工作目录已切换到: /content/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing

# %% [markdown]
# EGFR target based training

# %%
# 确保安装了依赖
# !pip install torch pandas numpy scikit-learn scipy -q

# 确保模型保存目录存在
# !mkdir -p models

# 运行脚本 (使用相对路径)
print("\n--- 运行 DeepDTA 训练脚本 ---")
# !python3 notebooks/model_DeepDTA.py
# Out:
# --- 运行 DeepDTA 训练脚本 ---
# 2025-10-26 20:42:20,118 - INFO - 使用的设备: cuda:0
# 2025-10-26 20:42:24,968 - INFO - 模型参数已初始化:
# 2025-10-26 20:42:24,968 - INFO -   - 化合物词汇量: 41, 最大长度: 248
# 2025-10-26 20:42:24,969 - INFO -   - 蛋白质词汇量: 21, 最大长度: 1210
# 2025-10-26 20:42:24,969 - INFO -   - 总样本数: 13286
# 2025-10-26 20:42:24,970 - INFO - 数据已划分 (训练: 10628, 验证: 1328, 测试: 1330)
# 2025-10-26 20:42:32,294 - INFO - Epoch 1/100 | 用时: 7.32s | 训练 MSE: 38.2375 | 验证 MSE: 14.1851 | 验证 Pearson: 0.2307
# 2025-10-26 20:42:32,302 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 14.1851)**
# 2025-10-26 20:42:37,311 - INFO - Epoch 2/100 | 用时: 5.01s | 训练 MSE: 4.9314 | 验证 MSE: 2.2286 | 验证 Pearson: 0.2761
# 2025-10-26 20:42:37,315 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 2.2286)**
# 2025-10-26 20:42:43,222 - INFO - Epoch 3/100 | 用时: 5.91s | 训练 MSE: 3.2615 | 验证 MSE: 2.3000 | 验证 Pearson: 0.3328
# 2025-10-26 20:42:48,410 - INFO - Epoch 4/100 | 用时: 5.19s | 训练 MSE: 3.0989 | 验证 MSE: 2.1367 | 验证 Pearson: 0.3815
# 2025-10-26 20:42:48,414 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 2.1367)**
# 2025-10-26 20:42:53,428 - INFO - Epoch 5/100 | 用时: 5.01s | 训练 MSE: 2.9614 | 验证 MSE: 2.0780 | 验证 Pearson: 0.4211
# 2025-10-26 20:42:53,432 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 2.0780)**
# 2025-10-26 20:42:59,475 - INFO - Epoch 6/100 | 用时: 6.04s | 训练 MSE: 2.8366 | 验证 MSE: 2.0175 | 验证 Pearson: 0.4522
# 2025-10-26 20:42:59,480 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 2.0175)**
# 2025-10-26 20:43:04,470 - INFO - Epoch 7/100 | 用时: 4.99s | 训练 MSE: 2.8011 | 验证 MSE: 2.0202 | 验证 Pearson: 0.4769
# 2025-10-26 20:43:10,496 - INFO - Epoch 8/100 | 用时: 6.03s | 训练 MSE: 2.6821 | 验证 MSE: 1.9043 | 验证 Pearson: 0.4952
# 2025-10-26 20:43:10,499 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.9043)**
# 2025-10-26 20:43:15,624 - INFO - Epoch 9/100 | 用时: 5.12s | 训练 MSE: 2.5861 | 验证 MSE: 1.8509 | 验证 Pearson: 0.5119
# 2025-10-26 20:43:15,628 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.8509)**
# 2025-10-26 20:43:21,367 - INFO - Epoch 10/100 | 用时: 5.74s | 训练 MSE: 2.4741 | 验证 MSE: 1.7948 | 验证 Pearson: 0.5244
# 2025-10-26 20:43:21,372 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.7948)**
# 2025-10-26 20:43:26,926 - INFO - Epoch 11/100 | 用时: 5.55s | 训练 MSE: 2.3993 | 验证 MSE: 1.7428 | 验证 Pearson: 0.5349
# 2025-10-26 20:43:26,930 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.7428)**
# 2025-10-26 20:43:31,989 - INFO - Epoch 12/100 | 用时: 5.06s | 训练 MSE: 2.3324 | 验证 MSE: 1.6983 | 验证 Pearson: 0.5433
# 2025-10-26 20:43:31,993 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.6983)**
# 2025-10-26 20:43:38,064 - INFO - Epoch 13/100 | 用时: 6.07s | 训练 MSE: 2.2798 | 验证 MSE: 1.6900 | 验证 Pearson: 0.5521
# 2025-10-26 20:43:38,068 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.6900)**
# 2025-10-26 20:43:43,259 - INFO - Epoch 14/100 | 用时: 5.19s | 训练 MSE: 2.2199 | 验证 MSE: 1.6502 | 验证 Pearson: 0.5587
# 2025-10-26 20:43:43,263 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.6502)**
# 2025-10-26 20:43:49,289 - INFO - Epoch 15/100 | 用时: 6.03s | 训练 MSE: 2.1914 | 验证 MSE: 1.6192 | 验证 Pearson: 0.5660
# 2025-10-26 20:43:49,292 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.6192)**
# 2025-10-26 20:43:54,439 - INFO - Epoch 16/100 | 用时: 5.15s | 训练 MSE: 2.1764 | 验证 MSE: 1.5979 | 验证 Pearson: 0.5728
# 2025-10-26 20:43:54,443 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.5979)**
# 2025-10-26 20:43:59,866 - INFO - Epoch 17/100 | 用时: 5.42s | 训练 MSE: 2.1235 | 验证 MSE: 1.6997 | 验证 Pearson: 0.5794
# 2025-10-26 20:44:05,621 - INFO - Epoch 18/100 | 用时: 5.75s | 训练 MSE: 2.1053 | 验证 MSE: 1.6064 | 验证 Pearson: 0.5867
# 2025-10-26 20:44:10,734 - INFO - Epoch 19/100 | 用时: 5.11s | 训练 MSE: 2.0482 | 验证 MSE: 1.5797 | 验证 Pearson: 0.5938
# 2025-10-26 20:44:10,737 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.5797)**
# 2025-10-26 20:44:16,801 - INFO - Epoch 20/100 | 用时: 6.06s | 训练 MSE: 2.0365 | 验证 MSE: 1.5653 | 验证 Pearson: 0.6002
# 2025-10-26 20:44:16,804 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.5653)**
# 2025-10-26 20:44:21,926 - INFO - Epoch 21/100 | 用时: 5.12s | 训练 MSE: 1.9949 | 验证 MSE: 1.5183 | 验证 Pearson: 0.6077
# 2025-10-26 20:44:21,931 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.5183)**
# 2025-10-26 20:44:28,028 - INFO - Epoch 22/100 | 用时: 6.10s | 训练 MSE: 1.9659 | 验证 MSE: 1.4861 | 验证 Pearson: 0.6146
# 2025-10-26 20:44:28,032 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.4861)**
# 2025-10-26 20:44:33,121 - INFO - Epoch 23/100 | 用时: 5.09s | 训练 MSE: 1.9141 | 验证 MSE: 1.4658 | 验证 Pearson: 0.6230
# 2025-10-26 20:44:33,126 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.4658)**
# 2025-10-26 20:44:38,449 - INFO - Epoch 24/100 | 用时: 5.32s | 训练 MSE: 1.8916 | 验证 MSE: 1.4211 | 验证 Pearson: 0.6323
# 2025-10-26 20:44:38,454 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.4211)**
# 2025-10-26 20:44:44,345 - INFO - Epoch 25/100 | 用时: 5.89s | 训练 MSE: 1.8641 | 验证 MSE: 1.3993 | 验证 Pearson: 0.6396
# 2025-10-26 20:44:44,349 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.3993)**
# 2025-10-26 20:44:49,517 - INFO - Epoch 26/100 | 用时: 5.17s | 训练 MSE: 1.8236 | 验证 MSE: 1.3750 | 验证 Pearson: 0.6477
# 2025-10-26 20:44:49,522 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.3750)**
# 2025-10-26 20:44:55,639 - INFO - Epoch 27/100 | 用时: 6.12s | 训练 MSE: 1.7959 | 验证 MSE: 1.3859 | 验证 Pearson: 0.6571
# 2025-10-26 20:45:00,740 - INFO - Epoch 28/100 | 用时: 5.10s | 训练 MSE: 1.8006 | 验证 MSE: 1.3489 | 验证 Pearson: 0.6649
# 2025-10-26 20:45:00,743 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.3489)**
# 2025-10-26 20:45:06,716 - INFO - Epoch 29/100 | 用时: 5.97s | 训练 MSE: 1.7487 | 验证 MSE: 1.2988 | 验证 Pearson: 0.6721
# 2025-10-26 20:45:06,721 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.2988)**
# 2025-10-26 20:45:12,121 - INFO - Epoch 30/100 | 用时: 5.40s | 训练 MSE: 1.7090 | 验证 MSE: 1.3005 | 验证 Pearson: 0.6791
# 2025-10-26 20:45:17,312 - INFO - Epoch 31/100 | 用时: 5.19s | 训练 MSE: 1.6704 | 验证 MSE: 1.2619 | 验证 Pearson: 0.6841
# 2025-10-26 20:45:17,318 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.2619)**
# 2025-10-26 20:45:23,395 - INFO - Epoch 32/100 | 用时: 6.08s | 训练 MSE: 1.6511 | 验证 MSE: 1.2345 | 验证 Pearson: 0.6916
# 2025-10-26 20:45:23,399 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.2345)**
# 2025-10-26 20:45:28,525 - INFO - Epoch 33/100 | 用时: 5.13s | 训练 MSE: 1.6176 | 验证 MSE: 1.3031 | 验证 Pearson: 0.6954
# 2025-10-26 20:45:34,575 - INFO - Epoch 34/100 | 用时: 6.05s | 训练 MSE: 1.6186 | 验证 MSE: 1.2034 | 验证 Pearson: 0.7005
# 2025-10-26 20:45:34,579 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.2034)**
# 2025-10-26 20:45:39,680 - INFO - Epoch 35/100 | 用时: 5.10s | 训练 MSE: 1.5846 | 验证 MSE: 1.1967 | 验证 Pearson: 0.7066
# 2025-10-26 20:45:39,684 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.1967)**
# 2025-10-26 20:45:45,606 - INFO - Epoch 36/100 | 用时: 5.92s | 训练 MSE: 1.5327 | 验证 MSE: 1.1835 | 验证 Pearson: 0.7089
# 2025-10-26 20:45:45,611 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.1835)**
# 2025-10-26 20:45:51,129 - INFO - Epoch 37/100 | 用时: 5.52s | 训练 MSE: 1.4855 | 验证 MSE: 1.2040 | 验证 Pearson: 0.7124
# 2025-10-26 20:45:56,297 - INFO - Epoch 38/100 | 用时: 5.17s | 训练 MSE: 1.4934 | 验证 MSE: 1.1559 | 验证 Pearson: 0.7173
# 2025-10-26 20:45:56,302 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.1559)**
# 2025-10-26 20:46:02,479 - INFO - Epoch 39/100 | 用时: 6.18s | 训练 MSE: 1.4869 | 验证 MSE: 1.1328 | 验证 Pearson: 0.7210
# 2025-10-26 20:46:02,483 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.1328)**
# 2025-10-26 20:46:07,538 - INFO - Epoch 40/100 | 用时: 5.05s | 训练 MSE: 1.4536 | 验证 MSE: 1.1651 | 验证 Pearson: 0.7240
# 2025-10-26 20:46:13,636 - INFO - Epoch 41/100 | 用时: 6.10s | 训练 MSE: 1.4500 | 验证 MSE: 1.1400 | 验证 Pearson: 0.7274
# 2025-10-26 20:46:18,726 - INFO - Epoch 42/100 | 用时: 5.09s | 训练 MSE: 1.4063 | 验证 MSE: 1.1145 | 验证 Pearson: 0.7301
# 2025-10-26 20:46:18,731 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.1145)**
# 2025-10-26 20:46:24,553 - INFO - Epoch 43/100 | 用时: 5.82s | 训练 MSE: 1.3761 | 验证 MSE: 1.0979 | 验证 Pearson: 0.7322
# 2025-10-26 20:46:24,562 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.0979)**
# 2025-10-26 20:46:30,097 - INFO - Epoch 44/100 | 用时: 5.54s | 训练 MSE: 1.3512 | 验证 MSE: 1.2854 | 验证 Pearson: 0.7359
# 2025-10-26 20:46:35,190 - INFO - Epoch 45/100 | 用时: 5.09s | 训练 MSE: 1.3686 | 验证 MSE: 1.1010 | 验证 Pearson: 0.7381
# 2025-10-26 20:46:41,243 - INFO - Epoch 46/100 | 用时: 6.05s | 训练 MSE: 1.3186 | 验证 MSE: 1.0670 | 验证 Pearson: 0.7401
# 2025-10-26 20:46:41,247 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.0670)**
# 2025-10-26 20:46:46,346 - INFO - Epoch 47/100 | 用时: 5.10s | 训练 MSE: 1.3118 | 验证 MSE: 1.0702 | 验证 Pearson: 0.7415
# 2025-10-26 20:46:52,439 - INFO - Epoch 48/100 | 用时: 6.09s | 训练 MSE: 1.3242 | 验证 MSE: 1.3359 | 验证 Pearson: 0.7455
# 2025-10-26 20:46:57,528 - INFO - Epoch 49/100 | 用时: 5.09s | 训练 MSE: 1.3616 | 验证 MSE: 1.0558 | 验证 Pearson: 0.7471
# 2025-10-26 20:46:57,532 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.0558)**
# 2025-10-26 20:47:03,020 - INFO - Epoch 50/100 | 用时: 5.49s | 训练 MSE: 1.2777 | 验证 MSE: 1.0605 | 验证 Pearson: 0.7488
# 2025-10-26 20:47:08,732 - INFO - Epoch 51/100 | 用时: 5.71s | 训练 MSE: 1.2277 | 验证 MSE: 1.0824 | 验证 Pearson: 0.7483
# 2025-10-26 20:47:13,786 - INFO - Epoch 52/100 | 用时: 5.05s | 训练 MSE: 1.2533 | 验证 MSE: 1.1628 | 验证 Pearson: 0.7513
# 2025-10-26 20:47:19,860 - INFO - Epoch 53/100 | 用时: 6.07s | 训练 MSE: 1.2387 | 验证 MSE: 1.0926 | 验证 Pearson: 0.7530
# 2025-10-26 20:47:25,076 - INFO - Epoch 54/100 | 用时: 5.22s | 训练 MSE: 1.2358 | 验证 MSE: 1.0676 | 验证 Pearson: 0.7527
# 2025-10-26 20:47:31,164 - INFO - Epoch 55/100 | 用时: 6.09s | 训练 MSE: 1.1971 | 验证 MSE: 1.0304 | 验证 Pearson: 0.7535
# 2025-10-26 20:47:31,168 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.0304)**
# 2025-10-26 20:47:36,256 - INFO - Epoch 56/100 | 用时: 5.09s | 训练 MSE: 1.2282 | 验证 MSE: 1.0324 | 验证 Pearson: 0.7552
# 2025-10-26 20:47:41,580 - INFO - Epoch 57/100 | 用时: 5.32s | 训练 MSE: 1.1930 | 验证 MSE: 1.0389 | 验证 Pearson: 0.7532
# 2025-10-26 20:47:47,397 - INFO - Epoch 58/100 | 用时: 5.82s | 训练 MSE: 1.1650 | 验证 MSE: 1.0153 | 验证 Pearson: 0.7578
# 2025-10-26 20:47:47,400 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.0153)**
# 2025-10-26 20:47:52,541 - INFO - Epoch 59/100 | 用时: 5.14s | 训练 MSE: 1.1770 | 验证 MSE: 1.0251 | 验证 Pearson: 0.7577
# 2025-10-26 20:47:58,577 - INFO - Epoch 60/100 | 用时: 6.04s | 训练 MSE: 1.1471 | 验证 MSE: 1.0069 | 验证 Pearson: 0.7585
# 2025-10-26 20:47:58,580 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.0069)**
# 2025-10-26 20:48:03,652 - INFO - Epoch 61/100 | 用时: 5.07s | 训练 MSE: 1.1469 | 验证 MSE: 1.0047 | 验证 Pearson: 0.7608
# 2025-10-26 20:48:03,656 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.0047)**
# 2025-10-26 20:48:09,542 - INFO - Epoch 62/100 | 用时: 5.89s | 训练 MSE: 1.1459 | 验证 MSE: 1.0213 | 验证 Pearson: 0.7600
# 2025-10-26 20:48:14,859 - INFO - Epoch 63/100 | 用时: 5.32s | 训练 MSE: 1.0927 | 验证 MSE: 1.0034 | 验证 Pearson: 0.7622
# 2025-10-26 20:48:14,866 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 1.0034)**
# 2025-10-26 20:48:20,125 - INFO - Epoch 64/100 | 用时: 5.26s | 训练 MSE: 1.0786 | 验证 MSE: 0.9972 | 验证 Pearson: 0.7628
# 2025-10-26 20:48:20,131 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 0.9972)**
# 2025-10-26 20:48:26,199 - INFO - Epoch 65/100 | 用时: 6.07s | 训练 MSE: 1.0796 | 验证 MSE: 1.0107 | 验证 Pearson: 0.7643
# 2025-10-26 20:48:31,357 - INFO - Epoch 66/100 | 用时: 5.16s | 训练 MSE: 1.0701 | 验证 MSE: 0.9948 | 验证 Pearson: 0.7629
# 2025-10-26 20:48:31,361 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 0.9948)**
# 2025-10-26 20:48:37,488 - INFO - Epoch 67/100 | 用时: 6.13s | 训练 MSE: 1.0600 | 验证 MSE: 1.0086 | 验证 Pearson: 0.7633
# 2025-10-26 20:48:42,630 - INFO - Epoch 68/100 | 用时: 5.14s | 训练 MSE: 1.0671 | 验证 MSE: 1.0513 | 验证 Pearson: 0.7642
# 2025-10-26 20:48:48,437 - INFO - Epoch 69/100 | 用时: 5.81s | 训练 MSE: 1.0879 | 验证 MSE: 1.0273 | 验证 Pearson: 0.7649
# 2025-10-26 20:48:53,988 - INFO - Epoch 70/100 | 用时: 5.55s | 训练 MSE: 1.0572 | 验证 MSE: 0.9823 | 验证 Pearson: 0.7657
# 2025-10-26 20:48:53,992 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 0.9823)**
# 2025-10-26 20:48:59,069 - INFO - Epoch 71/100 | 用时: 5.08s | 训练 MSE: 1.0626 | 验证 MSE: 0.9878 | 验证 Pearson: 0.7665
# 2025-10-26 20:49:05,266 - INFO - Epoch 72/100 | 用时: 6.20s | 训练 MSE: 1.0488 | 验证 MSE: 1.0359 | 验证 Pearson: 0.7650
# 2025-10-26 20:49:10,336 - INFO - Epoch 73/100 | 用时: 5.07s | 训练 MSE: 1.0437 | 验证 MSE: 0.9791 | 验证 Pearson: 0.7676
# 2025-10-26 20:49:10,340 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 0.9791)**
# 2025-10-26 20:49:16,406 - INFO - Epoch 74/100 | 用时: 6.07s | 训练 MSE: 1.0267 | 验证 MSE: 0.9875 | 验证 Pearson: 0.7675
# 2025-10-26 20:49:21,502 - INFO - Epoch 75/100 | 用时: 5.10s | 训练 MSE: 1.0509 | 验证 MSE: 0.9799 | 验证 Pearson: 0.7687
# 2025-10-26 20:49:27,217 - INFO - Epoch 76/100 | 用时: 5.71s | 训练 MSE: 1.0181 | 验证 MSE: 1.0185 | 验证 Pearson: 0.7680
# 2025-10-26 20:49:32,846 - INFO - Epoch 77/100 | 用时: 5.63s | 训练 MSE: 1.0027 | 验证 MSE: 1.0356 | 验证 Pearson: 0.7695
# 2025-10-26 20:49:37,975 - INFO - Epoch 78/100 | 用时: 5.13s | 训练 MSE: 0.9907 | 验证 MSE: 0.9986 | 验证 Pearson: 0.7694
# 2025-10-26 20:49:44,070 - INFO - Epoch 79/100 | 用时: 6.09s | 训练 MSE: 0.9848 | 验证 MSE: 0.9779 | 验证 Pearson: 0.7692
# 2025-10-26 20:49:44,074 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 0.9779)**
# 2025-10-26 20:49:49,130 - INFO - Epoch 80/100 | 用时: 5.06s | 训练 MSE: 0.9723 | 验证 MSE: 1.0088 | 验证 Pearson: 0.7697
# 2025-10-26 20:49:55,267 - INFO - Epoch 81/100 | 用时: 6.14s | 训练 MSE: 0.9583 | 验证 MSE: 0.9929 | 验证 Pearson: 0.7703
# 2025-10-26 20:50:00,413 - INFO - Epoch 82/100 | 用时: 5.15s | 训练 MSE: 0.9905 | 验证 MSE: 1.0851 | 验证 Pearson: 0.7676
# 2025-10-26 20:50:05,886 - INFO - Epoch 83/100 | 用时: 5.47s | 训练 MSE: 0.9533 | 验证 MSE: 0.9986 | 验证 Pearson: 0.7702
# 2025-10-26 20:50:11,778 - INFO - Epoch 84/100 | 用时: 5.89s | 训练 MSE: 0.9667 | 验证 MSE: 0.9784 | 验证 Pearson: 0.7712
# 2025-10-26 20:50:16,844 - INFO - Epoch 85/100 | 用时: 5.07s | 训练 MSE: 0.9452 | 验证 MSE: 1.0802 | 验证 Pearson: 0.7708
# 2025-10-26 20:50:22,988 - INFO - Epoch 86/100 | 用时: 6.14s | 训练 MSE: 0.9580 | 验证 MSE: 1.0416 | 验证 Pearson: 0.7723
# 2025-10-26 20:50:28,131 - INFO - Epoch 87/100 | 用时: 5.14s | 训练 MSE: 0.9402 | 验证 MSE: 0.9673 | 验证 Pearson: 0.7718
# 2025-10-26 20:50:28,134 - INFO - **模型已保存至 models/deepdta_egfr_best.pt (验证损失: 0.9673)**
# 2025-10-26 20:50:34,254 - INFO - Epoch 88/100 | 用时: 6.12s | 训练 MSE: 0.9415 | 验证 MSE: 1.0160 | 验证 Pearson: 0.7712
# 2025-10-26 20:50:39,556 - INFO - Epoch 89/100 | 用时: 5.30s | 训练 MSE: 0.9370 | 验证 MSE: 0.9993 | 验证 Pearson: 0.7714
# 2025-10-26 20:50:45,131 - INFO - Epoch 90/100 | 用时: 5.58s | 训练 MSE: 0.9146 | 验证 MSE: 0.9867 | 验证 Pearson: 0.7694
# 2025-10-26 20:50:50,977 - INFO - Epoch 91/100 | 用时: 5.85s | 训练 MSE: 0.8946 | 验证 MSE: 0.9816 | 验证 Pearson: 0.7697
# 2025-10-26 20:50:56,086 - INFO - Epoch 92/100 | 用时: 5.11s | 训练 MSE: 0.9147 | 验证 MSE: 0.9720 | 验证 Pearson: 0.7706
# 2025-10-26 20:51:02,111 - INFO - Epoch 93/100 | 用时: 6.02s | 训练 MSE: 0.9159 | 验证 MSE: 0.9880 | 验证 Pearson: 0.7697
# 2025-10-26 20:51:07,169 - INFO - Epoch 94/100 | 用时: 5.06s | 训练 MSE: 0.8921 | 验证 MSE: 0.9927 | 验证 Pearson: 0.7701
# 2025-10-26 20:51:13,315 - INFO - Epoch 95/100 | 用时: 6.15s | 训练 MSE: 0.8810 | 验证 MSE: 0.9735 | 验证 Pearson: 0.7709
# 2025-10-26 20:51:18,483 - INFO - Epoch 96/100 | 用时: 5.17s | 训练 MSE: 0.9049 | 验证 MSE: 0.9881 | 验证 Pearson: 0.7703
# 2025-10-26 20:51:23,893 - INFO - Epoch 97/100 | 用时: 5.41s | 训练 MSE: 0.8719 | 验证 MSE: 1.0335 | 验证 Pearson: 0.7688
# 2025-10-26 20:51:29,860 - INFO - Epoch 98/100 | 用时: 5.97s | 训练 MSE: 0.9079 | 验证 MSE: 1.0076 | 验证 Pearson: 0.7690
# 2025-10-26 20:51:35,006 - INFO - Epoch 99/100 | 用时: 5.15s | 训练 MSE: 0.9381 | 验证 MSE: 0.9763 | 验证 Pearson: 0.7708
# 2025-10-26 20:51:41,162 - INFO - Epoch 100/100 | 用时: 6.16s | 训练 MSE: 0.8647 | 验证 MSE: 0.9846 | 验证 Pearson: 0.7716
# 2025-10-26 20:51:41,162 - INFO - --------------------------------------------------
# 2025-10-26 20:51:41,162 - INFO - 开始最终测试...
# 2025-10-26 20:51:41,587 - INFO - --- 测试集最终结果 ---
# 2025-10-26 20:51:41,587 - INFO - 测试集 MSE: 0.8726
# 2025-10-26 20:51:41,587 - INFO - 测试集 Pearson 相关系数: 0.7844
# 2025-10-26 20:51:41,587 - INFO - DeepDTA 模型训练阶段完成。

# %% [markdown]
# Train-target training

# %%
# !python3 src/deepdta_model.py
# Out:
# 2025-10-26 21:57:47.882138: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761515867.902137   22702 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761515867.908236   22702 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761515867.924143   22702 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761515867.924168   22702 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761515867.924172   22702 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761515867.924178   22702 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# --- 尝试加载编码字典文件 ---
# ✅ 编码字典加载成功。SMILES 词汇表大小: 41, 蛋白词汇表大小: 21
#
# --- 1. 数据加载与预处理 ---
# ✅ 数据集加载成功，总计 13286 条有效记录。
# 开始编码药物 SMILES 和靶标序列...
# 训练集样本数: 10628, 测试集样本数: 2658
#
# --- 2. 构建 DeepDTA 模型 (已修正卷积块数量) ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 2025-10-26 21:57:54.538027: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1761515874.538182   22702 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# SMILES CNN 块数: 4 (序列长度 100 限制)
# Protein CNN 块数: 4 (序列长度 1000 限制)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ Drug_Input          │ (None, 100)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Target_Input        │ (None, 1000)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Drug_Embedding      │ (None, 100, 128)  │      5,248 │ Drug_Input[0][0]  │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Target_Embedding    │ (None, 1000, 128) │      2,688 │ Target_Input[0][… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 97, 32)    │     16,416 │ Drug_Embedding[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 993, 32)   │     32,800 │ Target_Embedding… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 48, 32)    │          0 │ conv1d[0][0]      │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_4     │ (None, 331, 32)   │          0 │ conv1d_4[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 45, 32)    │      4,128 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 324, 32)   │      8,224 │ max_pooling1d_4[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 22, 32)    │          0 │ conv1d_1[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_5     │ (None, 108, 32)   │          0 │ conv1d_5[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 19, 32)    │      4,128 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 101, 32)   │      8,224 │ max_pooling1d_5[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_2     │ (None, 9, 32)     │          0 │ conv1d_2[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_6     │ (None, 33, 32)    │          0 │ conv1d_6[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 6, 32)     │      4,128 │ max_pooling1d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 26, 32)    │      8,224 │ max_pooling1d_6[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_3     │ (None, 3, 32)     │          0 │ conv1d_3[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_7     │ (None, 8, 32)     │          0 │ conv1d_7[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Drug_Flatten        │ (None, 96)        │          0 │ max_pooling1d_3[… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Target_Flatten      │ (None, 256)       │          0 │ max_pooling1d_7[… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 352)       │          0 │ Drug_Flatten[0][… │
# │ (Concatenate)       │                   │            │ Target_Flatten[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1024)      │    361,472 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1024)      │  1,049,600 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 512)       │    524,800 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Prediction_Output   │ (None, 1)         │        513 │ dense_2[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,030,593 (7.75 MB)
#  Trainable params: 2,030,593 (7.75 MB)
#  Non-trainable params: 0 (0.00 B)
#
# --- 3. 模型训练/加载步骤 ---
# 开始模型训练...
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761515878.623548   22753 service.cc:152] XLA service 0x7e00c4002130 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761515878.623589   22753 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1761515879.302828   22753 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1761515885.118678   22753 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#
# Epoch 1: val_loss improved from inf to 1.96172, saving model to best_deepdta_model.keras
# 84/84 - 18s - 217ms/step - loss: 6.8436 - mae: 1.9037 - mse: 6.8436 - val_loss: 1.9617 - val_mae: 1.1332 - val_mse: 1.9617
# Epoch 2/100
#
# Epoch 2: val_loss improved from 1.96172 to 1.64228, saving model to best_deepdta_model.keras
# 84/84 - 2s - 27ms/step - loss: 1.7760 - mae: 1.0732 - mse: 1.7760 - val_loss: 1.6423 - val_mae: 1.0161 - val_mse: 1.6423
# Epoch 3/100
#
# Epoch 3: val_loss improved from 1.64228 to 1.47189, saving model to best_deepdta_model.keras
# 84/84 - 2s - 29ms/step - loss: 1.4507 - mae: 0.9520 - mse: 1.4507 - val_loss: 1.4719 - val_mae: 0.9487 - val_mse: 1.4719
# Epoch 4/100
#
# Epoch 4: val_loss improved from 1.47189 to 1.32608, saving model to best_deepdta_model.keras
# 84/84 - 2s - 29ms/step - loss: 1.2587 - mae: 0.8793 - mse: 1.2587 - val_loss: 1.3261 - val_mae: 0.8824 - val_mse: 1.3261
# Epoch 5/100
#
# Epoch 5: val_loss improved from 1.32608 to 1.21670, saving model to best_deepdta_model.keras
# 84/84 - 2s - 28ms/step - loss: 1.1607 - mae: 0.8451 - mse: 1.1607 - val_loss: 1.2167 - val_mae: 0.8422 - val_mse: 1.2167
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 1.21670
# 84/84 - 2s - 26ms/step - loss: 1.0512 - mae: 0.8016 - mse: 1.0512 - val_loss: 1.3199 - val_mae: 0.8949 - val_mse: 1.3199
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 1.21670
# 84/84 - 2s - 26ms/step - loss: 0.9141 - mae: 0.7403 - mse: 0.9141 - val_loss: 1.3045 - val_mae: 0.8866 - val_mse: 1.3045
# Epoch 8/100
#
# Epoch 8: val_loss improved from 1.21670 to 1.08680, saving model to best_deepdta_model.keras
# 84/84 - 2s - 28ms/step - loss: 0.9054 - mae: 0.7384 - mse: 0.9054 - val_loss: 1.0868 - val_mae: 0.7895 - val_mse: 1.0868
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 1.08680
# 84/84 - 2s - 27ms/step - loss: 0.8108 - mae: 0.6980 - mse: 0.8108 - val_loss: 1.0992 - val_mae: 0.7908 - val_mse: 1.0992
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 1.08680
# 84/84 - 2s - 26ms/step - loss: 0.7516 - mae: 0.6735 - mse: 0.7516 - val_loss: 2.2317 - val_mae: 1.2212 - val_mse: 2.2317
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 1.08680
# 84/84 - 2s - 25ms/step - loss: 0.8016 - mae: 0.6970 - mse: 0.8016 - val_loss: 1.0997 - val_mae: 0.7857 - val_mse: 1.0997
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 1.08680
# 84/84 - 2s - 25ms/step - loss: 0.6546 - mae: 0.6244 - mse: 0.6546 - val_loss: 1.2100 - val_mae: 0.8420 - val_mse: 1.2100
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 1.08680
# 84/84 - 2s - 26ms/step - loss: 0.6763 - mae: 0.6348 - mse: 0.6763 - val_loss: 1.2785 - val_mae: 0.8709 - val_mse: 1.2785
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 1.08680
# 84/84 - 2s - 26ms/step - loss: 0.6821 - mae: 0.6364 - mse: 0.6821 - val_loss: 1.1192 - val_mae: 0.7906 - val_mse: 1.1192
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 1.08680
# 84/84 - 2s - 27ms/step - loss: 0.5884 - mae: 0.5909 - mse: 0.5884 - val_loss: 1.1085 - val_mae: 0.7926 - val_mse: 1.1085
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 1.08680
# 84/84 - 2s - 26ms/step - loss: 0.5980 - mae: 0.5965 - mse: 0.5980 - val_loss: 1.9103 - val_mae: 1.1274 - val_mse: 1.9103
# Epoch 17/100
#
# Epoch 17: val_loss improved from 1.08680 to 1.07722, saving model to best_deepdta_model.keras
# 84/84 - 2s - 28ms/step - loss: 0.7774 - mae: 0.6875 - mse: 0.7774 - val_loss: 1.0772 - val_mae: 0.7698 - val_mse: 1.0772
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 1.07722
# 84/84 - 2s - 26ms/step - loss: 0.5309 - mae: 0.5606 - mse: 0.5309 - val_loss: 3.0290 - val_mae: 1.4780 - val_mse: 3.0290
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 1.07722
# 84/84 - 2s - 26ms/step - loss: 0.8237 - mae: 0.7101 - mse: 0.8237 - val_loss: 1.1774 - val_mae: 0.8196 - val_mse: 1.1774
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 1.07722
# 84/84 - 2s - 28ms/step - loss: 0.5554 - mae: 0.5770 - mse: 0.5554 - val_loss: 1.2102 - val_mae: 0.8325 - val_mse: 1.2102
# Epoch 21/100
#
# Epoch 21: val_loss improved from 1.07722 to 1.06336, saving model to best_deepdta_model.keras
# 84/84 - 3s - 31ms/step - loss: 0.5354 - mae: 0.5684 - mse: 0.5354 - val_loss: 1.0634 - val_mae: 0.7602 - val_mse: 1.0634
# Epoch 22/100
#
# Epoch 22: val_loss improved from 1.06336 to 1.05511, saving model to best_deepdta_model.keras
# 84/84 - 2s - 28ms/step - loss: 0.4667 - mae: 0.5268 - mse: 0.4667 - val_loss: 1.0551 - val_mae: 0.7566 - val_mse: 1.0551
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 1.05511
# 84/84 - 2s - 26ms/step - loss: 0.5024 - mae: 0.5480 - mse: 0.5024 - val_loss: 1.9583 - val_mae: 1.1313 - val_mse: 1.9583
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 1.05511
# 84/84 - 2s - 26ms/step - loss: 0.5911 - mae: 0.5985 - mse: 0.5911 - val_loss: 1.1019 - val_mae: 0.7840 - val_mse: 1.1019
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 1.05511
# 84/84 - 2s - 26ms/step - loss: 0.4735 - mae: 0.5315 - mse: 0.4735 - val_loss: 1.2086 - val_mae: 0.8244 - val_mse: 1.2086
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 1.05511
# 84/84 - 2s - 27ms/step - loss: 0.4229 - mae: 0.4970 - mse: 0.4229 - val_loss: 1.8403 - val_mae: 1.0974 - val_mse: 1.8403
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 1.05511
# 84/84 - 2s - 27ms/step - loss: 0.5008 - mae: 0.5490 - mse: 0.5008 - val_loss: 1.0581 - val_mae: 0.7646 - val_mse: 1.0581
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 1.05511
# 84/84 - 2s - 26ms/step - loss: 0.4044 - mae: 0.4893 - mse: 0.4044 - val_loss: 1.9906 - val_mae: 1.1517 - val_mse: 1.9906
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 1.05511
# 84/84 - 2s - 26ms/step - loss: 0.4801 - mae: 0.5396 - mse: 0.4801 - val_loss: 1.1600 - val_mae: 0.8076 - val_mse: 1.1600
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 1.05511
# 84/84 - 2s - 26ms/step - loss: 0.3572 - mae: 0.4593 - mse: 0.3572 - val_loss: 1.1042 - val_mae: 0.7779 - val_mse: 1.1042
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 1.05511
# 84/84 - 2s - 26ms/step - loss: 0.3480 - mae: 0.4550 - mse: 0.3480 - val_loss: 1.1456 - val_mae: 0.7986 - val_mse: 1.1456
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 1.05511
# 84/84 - 2s - 27ms/step - loss: 0.3214 - mae: 0.4339 - mse: 0.3214 - val_loss: 1.1369 - val_mae: 0.7979 - val_mse: 1.1369
# Epoch 32: early stopping
# 训练完成。最佳模型已保存到 best_deepdta_model.keras

# %% [markdown]
# Train-target prediction

# %%
# !python3 src/deepdta_workflow.py
# Out:
# 2025-10-26 22:04:42.197915: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761516282.217504   25018 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761516282.223926   25018 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761516282.239139   25018 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761516282.239163   25018 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761516282.239167   25018 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761516282.239170   25018 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# --- 尝试加载编码字典文件 ---
# ✅ 编码字典加载成功。SMILES 词汇表大小: 41, 蛋白词汇表大小: 21
#
# --- 1. 数据加载与预处理 ---
# ✅ 数据集加载成功，总计 13286 条有效记录。
# 开始编码药物 SMILES 和靶标序列...
# 训练集样本数: 10628, 测试集样本数: 2658
#
# --- 2. 构建 DeepDTA 模型 (已修正卷积块数量) ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 2025-10-26 22:04:48.788803: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1761516288.788943   25018 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# SMILES CNN 块数: 4 (序列长度 100 限制)
# Protein CNN 块数: 4 (序列长度 1000 限制)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ Drug_Input          │ (None, 100)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Target_Input        │ (None, 1000)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Drug_Embedding      │ (None, 100, 128)  │      5,248 │ Drug_Input[0][0]  │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Target_Embedding    │ (None, 1000, 128) │      2,688 │ Target_Input[0][… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 97, 32)    │     16,416 │ Drug_Embedding[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 993, 32)   │     32,800 │ Target_Embedding… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 48, 32)    │          0 │ conv1d[0][0]      │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_4     │ (None, 331, 32)   │          0 │ conv1d_4[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 45, 32)    │      4,128 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 324, 32)   │      8,224 │ max_pooling1d_4[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 22, 32)    │          0 │ conv1d_1[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_5     │ (None, 108, 32)   │          0 │ conv1d_5[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 19, 32)    │      4,128 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 101, 32)   │      8,224 │ max_pooling1d_5[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_2     │ (None, 9, 32)     │          0 │ conv1d_2[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_6     │ (None, 33, 32)    │          0 │ conv1d_6[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 6, 32)     │      4,128 │ max_pooling1d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 26, 32)    │      8,224 │ max_pooling1d_6[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_3     │ (None, 3, 32)     │          0 │ conv1d_3[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_7     │ (None, 8, 32)     │          0 │ conv1d_7[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Drug_Flatten        │ (None, 96)        │          0 │ max_pooling1d_3[… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Target_Flatten      │ (None, 256)       │          0 │ max_pooling1d_7[… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 352)       │          0 │ Drug_Flatten[0][… │
# │ (Concatenate)       │                   │            │ Target_Flatten[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1024)      │    361,472 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1024)      │  1,049,600 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 512)       │    524,800 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Prediction_Output   │ (None, 1)         │        513 │ dense_2[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,030,593 (7.75 MB)
#  Trainable params: 2,030,593 (7.75 MB)
#  Non-trainable params: 0 (0.00 B)
#
# --- 3. 模型训练/加载步骤 ---
# 开始模型训练...
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761516292.914099   25071 service.cc:152] XLA service 0x7e471c01ad00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761516292.914132   25071 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1761516293.532317   25071 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1761516298.968541   25071 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#
# Epoch 1: val_loss improved from inf to 1.84653, saving model to best_deepdta_model.keras
# 84/84 - 18s - 211ms/step - loss: 4.3429 - mae: 1.5292 - mse: 4.3429 - val_loss: 1.8465 - val_mae: 1.0942 - val_mse: 1.8465
# Epoch 2/100
#
# Epoch 2: val_loss did not improve from 1.84653
# 84/84 - 2s - 25ms/step - loss: 1.6686 - mae: 1.0358 - mse: 1.6686 - val_loss: 2.3668 - val_mae: 1.2486 - val_mse: 2.3668
# Epoch 3/100
#
# Epoch 3: val_loss improved from 1.84653 to 1.40656, saving model to best_deepdta_model.keras
# 84/84 - 2s - 29ms/step - loss: 1.4776 - mae: 0.9630 - mse: 1.4776 - val_loss: 1.4066 - val_mae: 0.9173 - val_mse: 1.4066
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 1.40656
# 84/84 - 2s - 27ms/step - loss: 1.2103 - mae: 0.8621 - mse: 1.2103 - val_loss: 1.4989 - val_mae: 0.9559 - val_mse: 1.4989
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 1.40656
# 84/84 - 2s - 25ms/step - loss: 1.1369 - mae: 0.8368 - mse: 1.1369 - val_loss: 2.0596 - val_mae: 1.1635 - val_mse: 2.0596
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 1.40656
# 84/84 - 2s - 26ms/step - loss: 1.0330 - mae: 0.7953 - mse: 1.0330 - val_loss: 2.1196 - val_mae: 1.1818 - val_mse: 2.1196
# Epoch 7/100
#
# Epoch 7: val_loss improved from 1.40656 to 1.18693, saving model to best_deepdta_model.keras
# 84/84 - 2s - 28ms/step - loss: 1.0590 - mae: 0.8057 - mse: 1.0590 - val_loss: 1.1869 - val_mae: 0.8213 - val_mse: 1.1869
# Epoch 8/100
#
# Epoch 8: val_loss improved from 1.18693 to 1.12615, saving model to best_deepdta_model.keras
# 84/84 - 2s - 28ms/step - loss: 0.8675 - mae: 0.7241 - mse: 0.8675 - val_loss: 1.1261 - val_mae: 0.8011 - val_mse: 1.1261
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 1.12615
# 84/84 - 2s - 27ms/step - loss: 0.8171 - mae: 0.7043 - mse: 0.8171 - val_loss: 1.2815 - val_mae: 0.8618 - val_mse: 1.2815
# Epoch 10/100
#
# Epoch 10: val_loss improved from 1.12615 to 1.11281, saving model to best_deepdta_model.keras
# 84/84 - 2s - 29ms/step - loss: 0.8014 - mae: 0.6964 - mse: 0.8014 - val_loss: 1.1128 - val_mae: 0.7875 - val_mse: 1.1128
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 1.11281
# 84/84 - 2s - 26ms/step - loss: 0.6864 - mae: 0.6363 - mse: 0.6864 - val_loss: 1.4768 - val_mae: 0.9549 - val_mse: 1.4768
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 1.11281
# 84/84 - 2s - 26ms/step - loss: 0.7240 - mae: 0.6571 - mse: 0.7240 - val_loss: 1.1326 - val_mae: 0.7919 - val_mse: 1.1326
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 1.11281
# 84/84 - 2s - 26ms/step - loss: 0.6443 - mae: 0.6222 - mse: 0.6443 - val_loss: 1.4638 - val_mae: 0.9391 - val_mse: 1.4638
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 1.11281
# 84/84 - 2s - 26ms/step - loss: 0.6464 - mae: 0.6240 - mse: 0.6464 - val_loss: 1.2145 - val_mae: 0.8196 - val_mse: 1.2145
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 1.11281
# 84/84 - 2s - 28ms/step - loss: 0.5829 - mae: 0.5912 - mse: 0.5829 - val_loss: 1.1685 - val_mae: 0.7999 - val_mse: 1.1685
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 1.11281
# 84/84 - 2s - 27ms/step - loss: 0.6194 - mae: 0.6097 - mse: 0.6194 - val_loss: 1.1560 - val_mae: 0.7977 - val_mse: 1.1560
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 1.11281
# 84/84 - 2s - 26ms/step - loss: 0.5421 - mae: 0.5691 - mse: 0.5421 - val_loss: 1.2135 - val_mae: 0.8267 - val_mse: 1.2135
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 1.11281
# 84/84 - 2s - 26ms/step - loss: 0.5463 - mae: 0.5709 - mse: 0.5463 - val_loss: 1.1451 - val_mae: 0.7910 - val_mse: 1.1451
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 1.11281
# 84/84 - 2s - 26ms/step - loss: 0.4908 - mae: 0.5409 - mse: 0.4908 - val_loss: 1.1217 - val_mae: 0.7772 - val_mse: 1.1217
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 1.11281
# 84/84 - 2s - 26ms/step - loss: 0.4296 - mae: 0.5034 - mse: 0.4296 - val_loss: 1.1363 - val_mae: 0.7870 - val_mse: 1.1363
# Epoch 20: early stopping
# 训练完成。最佳模型已保存到 best_deepdta_model.keras
#
# --- 4. 开始预测跨靶点亲和力 (CFTR) ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#      Drug Name    Target Name  Predicted pIC50
# 0  Semaglutide  CFTR (P13569)         6.201048
# 1  Tirzepatide  CFTR (P13569)         7.230276
#
# 💡 结果解读：预测的 pIC50 值越高，预测的亲和力越强（效价越高）。
#    该预测是基于 EGFR (CHEMBL203) 数据训练的模型进行的药物重定位探索。

# %%
# !pip install rdkit
# !python3 src/visualize_pipeline.py
# Out:
# Requirement already satisfied: rdkit in /usr/local/lib/python3.12/dist-packages (2025.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)
# 2025-10-26 22:25:31,911 - INFO - --- 启动药物结构分析与可视化 ---
# 2025-10-26 22:25:31,912 - INFO - 输出目录已确认: reports/figures
#
# --- 简化药物结构理化性质摘要 ---
#
# | Drug Name   | SMILES                                         |   MW (g/mol) |   LogP |   H Donors |   H Acceptors |
# |:------------|:-----------------------------------------------|-------------:|-------:|-----------:|--------------:|
# | Semaglutide | CCCCCCCCCCCCCCCCCC(=O)NCCc1ccc(C(=O)O)cc1      |      431.661 | 7.305  |          2 |             2 |
# | Tirzepatide | CCCCCCCCCCCCCCCCCCCC(=O)NCCc1cc(N)c(C(=O)O)cc1 |      474.73  | 7.6674 |          3 |             3 |
#
# ----------------------------------
#
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:94: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:94: UserWarning: Glyph 23376 (\N{CJK UNIFIED IDEOGRAPH-5B50}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:94: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:94: UserWarning: Glyph 36136 (\N{CJK UNIFIED IDEOGRAPH-8D28}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:94: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:94: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:94: UserWarning: Glyph 19982 (\N{CJK UNIFIED IDEOGRAPH-4E0E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:94: UserWarning: Glyph 31616 (\N{CJK UNIFIED IDEOGRAPH-7B80}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:94: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:94: UserWarning: Glyph 32467 (\N{CJK UNIFIED IDEOGRAPH-7ED3}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:94: UserWarning: Glyph 26500 (\N{CJK UNIFIED IDEOGRAPH-6784}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:94: UserWarning: Glyph 29702 (\N{CJK UNIFIED IDEOGRAPH-7406}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:94: UserWarning: Glyph 23545 (\N{CJK UNIFIED IDEOGRAPH-5BF9}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:94: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:94: UserWarning: Glyph 33647 (\N{CJK UNIFIED IDEOGRAPH-836F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:94: UserWarning: Glyph 29289 (\N{CJK UNIFIED IDEOGRAPH-7269}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:95: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'physicochemical_comparison.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:95: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'physicochemical_comparison.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:95: UserWarning: Glyph 19982 (\N{CJK UNIFIED IDEOGRAPH-4E0E}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'physicochemical_comparison.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:95: UserWarning: Glyph 31616 (\N{CJK UNIFIED IDEOGRAPH-7B80}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'physicochemical_comparison.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:95: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'physicochemical_comparison.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:95: UserWarning: Glyph 32467 (\N{CJK UNIFIED IDEOGRAPH-7ED3}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'physicochemical_comparison.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:95: UserWarning: Glyph 26500 (\N{CJK UNIFIED IDEOGRAPH-6784}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'physicochemical_comparison.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:95: UserWarning: Glyph 29702 (\N{CJK UNIFIED IDEOGRAPH-7406}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'physicochemical_comparison.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:95: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'physicochemical_comparison.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:95: UserWarning: Glyph 36136 (\N{CJK UNIFIED IDEOGRAPH-8D28}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'physicochemical_comparison.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:95: UserWarning: Glyph 23545 (\N{CJK UNIFIED IDEOGRAPH-5BF9}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'physicochemical_comparison.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:95: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'physicochemical_comparison.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:95: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'physicochemical_comparison.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:95: UserWarning: Glyph 23376 (\N{CJK UNIFIED IDEOGRAPH-5B50}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'physicochemical_comparison.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:95: UserWarning: Glyph 33647 (\N{CJK UNIFIED IDEOGRAPH-836F}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'physicochemical_comparison.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:95: UserWarning: Glyph 29289 (\N{CJK UNIFIED IDEOGRAPH-7269}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'physicochemical_comparison.png', dpi=300)
# 2025-10-26 22:25:32,515 - INFO - 理化性质对比图已保存至: reports/figures/physicochemical_comparison.png
# [22:25:32] DEPRECATION WARNING: please use MorganGenerator
# [22:25:32] DEPRECATION WARNING: please use MorganGenerator
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:132: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:132: UserWarning: Glyph 20284 (\N{CJK UNIFIED IDEOGRAPH-4F3C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:132: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:132: UserWarning: Glyph 31616 (\N{CJK UNIFIED IDEOGRAPH-7B80}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:132: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:132: UserWarning: Glyph 32467 (\N{CJK UNIFIED IDEOGRAPH-7ED3}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:132: UserWarning: Glyph 26500 (\N{CJK UNIFIED IDEOGRAPH-6784}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:133: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'structural_similarity.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:133: UserWarning: Glyph 20284 (\N{CJK UNIFIED IDEOGRAPH-4F3C}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'structural_similarity.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:133: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'structural_similarity.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:133: UserWarning: Glyph 31616 (\N{CJK UNIFIED IDEOGRAPH-7B80}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'structural_similarity.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:133: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'structural_similarity.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:133: UserWarning: Glyph 32467 (\N{CJK UNIFIED IDEOGRAPH-7ED3}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'structural_similarity.png', dpi=300)
# /content/drive/MyDrive/DDLS_Drug_Repurposing/DDLS_Drug_Repurposing/src/visualize_pipeline.py:133: UserWarning: Glyph 26500 (\N{CJK UNIFIED IDEOGRAPH-6784}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path / 'structural_similarity.png', dpi=300)
# 2025-10-26 22:25:32,706 - INFO - 结构相似性图已保存至: reports/figures/structural_similarity.png
# 2025-10-26 22:25:32,706 - INFO -
# --- 可视化分析完成 ---
# 生成的图像文件可在 reports/figures 路径下查看:
#  - physicochemical_comparison.png (理化性质对比图)
#  - structural_similarity.png (结构相似性图)
#
# >>> 可视化洞察：Tirzepatide (C20侧链) 相较于 Semaglutide (C18侧链) 表现出更高的分子量和 LogP，这可能赋予其更好的膜渗透性和与 CFTR 脂质环境结合的能力。此外，Tirzepatide 额外的氢键供体/受体（简化结构中为 +1）可能为 CFTR 结合提供了额外的锚定点。
